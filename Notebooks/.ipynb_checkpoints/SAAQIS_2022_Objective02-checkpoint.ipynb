# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Import-libraries" data-toc-modified-id="Import-libraries-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Import libraries</a></span></li><li><span><a href="#Functions" data-toc-modified-id="Functions-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Functions</a></span></li><li><span><a href="#Visualisation-functions" data-toc-modified-id="Visualisation-functions-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Visualisation functions</a></span></li><li><span><a href="#Directories" data-toc-modified-id="Directories-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Directories</a></span><ul class="toc-item"><li><span><a href="#Import-AQMS-Data" data-toc-modified-id="Import-AQMS-Data-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Import AQMS Data</a></span><ul class="toc-item"><li><span><a href="#Make-sure-Time-Zone-is-local" data-toc-modified-id="Make-sure-Time-Zone-is-local-4.1.1"><span class="toc-item-num">4.1.1&nbsp;&nbsp;</span>Make sure Time Zone is local</a></span></li></ul></li></ul></li><li><span><a href="#Objective-02:-Radar-observations-of-plumes" data-toc-modified-id="Objective-02:-Radar-observations-of-plumes-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Objective 02: Radar observations of plumes</a></span><ul class="toc-item"><li><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Import-stations" data-toc-modified-id="Import-stations-5.0.0.1"><span class="toc-item-num">5.0.0.1&nbsp;&nbsp;</span>Import stations</a></span></li><li><span><a href="#Import-radar" data-toc-modified-id="Import-radar-5.0.0.2"><span class="toc-item-num">5.0.0.2&nbsp;&nbsp;</span>Import radar</a></span></li><li><span><a href="#Import-country" data-toc-modified-id="Import-country-5.0.0.3"><span class="toc-item-num">5.0.0.3&nbsp;&nbsp;</span>Import country</a></span></li></ul></li><li><span><a href="#Reproject-Layers-to-Hartebeeshoek-EPSG:9221" data-toc-modified-id="Reproject-Layers-to-Hartebeeshoek-EPSG:9221-5.0.1"><span class="toc-item-num">5.0.1&nbsp;&nbsp;</span>Reproject Layers to Hartebeeshoek EPSG:9221</a></span></li></ul></li><li><span><a href="#Days-with-plumes" data-toc-modified-id="Days-with-plumes-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Days with plumes</a></span></li><li><span><a href="#Radar-Data:-dBZ" data-toc-modified-id="Radar-Data:-dBZ-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Radar Data: dBZ</a></span><ul class="toc-item"><li><span><a href="#Import-extracted-data" data-toc-modified-id="Import-extracted-data-5.2.1"><span class="toc-item-num">5.2.1&nbsp;&nbsp;</span>Import extracted data</a></span></li><li><span><a href="#Make-sure-Extracted-DBZ-is-in-Local-Time" data-toc-modified-id="Make-sure-Extracted-DBZ-is-in-Local-Time-5.2.2"><span class="toc-item-num">5.2.2&nbsp;&nbsp;</span>Make sure Extracted DBZ is in Local Time</a></span></li><li><span><a href="#Merge-with-Level0-Data" data-toc-modified-id="Merge-with-Level0-Data-5.2.3"><span class="toc-item-num">5.2.3&nbsp;&nbsp;</span>Merge with Level0 Data</a></span></li></ul></li></ul></li><li><span><a href="#Plume-Tracks" data-toc-modified-id="Plume-Tracks-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Plume Tracks</a></span><ul class="toc-item"><li><span><a href="#Import-tracks" data-toc-modified-id="Import-tracks-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Import tracks</a></span><ul class="toc-item"><li><span><a href="#Import-fire-occurances" data-toc-modified-id="Import-fire-occurances-6.1.1"><span class="toc-item-num">6.1.1&nbsp;&nbsp;</span>Import fire occurances</a></span><ul class="toc-item"><li><span><a href="#MODIS-Thermal-Anomalies" data-toc-modified-id="MODIS-Thermal-Anomalies-6.1.1.1"><span class="toc-item-num">6.1.1.1&nbsp;&nbsp;</span>MODIS Thermal Anomalies</a></span></li><li><span><a href="#VIIRS-Thermal-Anomalies" data-toc-modified-id="VIIRS-Thermal-Anomalies-6.1.1.2"><span class="toc-item-num">6.1.1.2&nbsp;&nbsp;</span>VIIRS Thermal Anomalies</a></span></li><li><span><a href="#Fire-Atlas" data-toc-modified-id="Fire-Atlas-6.1.1.3"><span class="toc-item-num">6.1.1.3&nbsp;&nbsp;</span>Fire Atlas</a></span></li></ul></li><li><span><a href="#Reproject-Layers-to-Hartebeeshoek-EPSG:9221" data-toc-modified-id="Reproject-Layers-to-Hartebeeshoek-EPSG:9221-6.1.2"><span class="toc-item-num">6.1.2&nbsp;&nbsp;</span>Reproject Layers to Hartebeeshoek EPSG:9221</a></span></li></ul></li></ul></li><li><span><a href="#Plume-impacts-on-AQMS-data" data-toc-modified-id="Plume-impacts-on-AQMS-data-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Plume impacts on AQMS data</a></span><ul class="toc-item"><li><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Check-CRS-of-input-files" data-toc-modified-id="Check-CRS-of-input-files-7.0.0.1"><span class="toc-item-num">7.0.0.1&nbsp;&nbsp;</span>Check CRS of input files</a></span></li></ul></li><li><span><a href="#Select-stations-in-polygon" data-toc-modified-id="Select-stations-in-polygon-7.0.1"><span class="toc-item-num">7.0.1&nbsp;&nbsp;</span>Select stations in polygon</a></span></li><li><span><a href="#Plot-tracks" data-toc-modified-id="Plot-tracks-7.0.2"><span class="toc-item-num">7.0.2&nbsp;&nbsp;</span>Plot tracks</a></span></li><li><span><a href="#Get-monitoring-data" data-toc-modified-id="Get-monitoring-data-7.0.3"><span class="toc-item-num">7.0.3&nbsp;&nbsp;</span>Get monitoring data</a></span><ul class="toc-item"><li><span><a href="#Check-for-monitoring-data" data-toc-modified-id="Check-for-monitoring-data-7.0.3.1"><span class="toc-item-num">7.0.3.1&nbsp;&nbsp;</span>Check for monitoring data</a></span></li><li><span><a href="#Functions-to-get-different-data-sources" data-toc-modified-id="Functions-to-get-different-data-sources-7.0.3.2"><span class="toc-item-num">7.0.3.2&nbsp;&nbsp;</span>Functions to get different data sources</a></span></li><li><span><a href="#Integrate-different-data-sources-and-plot-the-Plume,-Radar-and-AQMS-data" data-toc-modified-id="Integrate-different-data-sources-and-plot-the-Plume,-Radar-and-AQMS-data-7.0.3.3"><span class="toc-item-num">7.0.3.3&nbsp;&nbsp;</span>Integrate different data sources and plot the Plume, Radar and AQMS data</a></span></li></ul></li></ul></li><li><span><a href="#Plot-XMLPlumes-and-Stations-Data" data-toc-modified-id="Plot-XMLPlumes-and-Stations-Data-7.1"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>Plot XMLPlumes and Stations Data</a></span></li></ul></li><li><span><a href="#Import-Shapefile-from-XML-Plumes" data-toc-modified-id="Import-Shapefile-from-XML-Plumes-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Import Shapefile from XML Plumes</a></span><ul class="toc-item"><li><span><a href="#Select-plumes-over-stations" data-toc-modified-id="Select-plumes-over-stations-8.1"><span class="toc-item-num">8.1&nbsp;&nbsp;</span>Select plumes over stations</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Import libraries

# %%
# The pandas data science library that gives the 'spreadsheet'-like capabilities to python
import pandas as pd
# The matplotlip library is used to visualize data
from matplotlib import rcParams
rcParams['font.family'] = 'serif'
import matplotlib.pyplot as plt
import matplotlib as mpl
from matplotlib.colors import BoundaryNorm
from matplotlib.ticker import MaxNLocator
import matplotlib.cm as cm
from matplotlib.dates import DateFormatter

# The pathlib library is used to manage access to disk. It helps us to keep things the same between Windows and Linux
from pathlib import Path
# The os library is used to list and access files and directories on the hard drive
import os, sys\
# Numpy is the numerical library. It is used by many of the ones before, but we import it for in case
import numpy as np
# From Numpy we also import the nan 'missing-value' object that we use alot
from numpy import nan
# For fancy matching of strings, we use re
import re
# String libary for temporary file import
from io import StringIO

# Library for manipulating date and time
import datetime 
# Scientif python library for statistics
from scipy import interpolate

#Figure style library
import seaborn as sns
sns.set_theme(style="darkgrid")
#Register pandas formatters and converters with matplotlib
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()
import re


import xarray as xr


import geopandas as gpd

import xml.etree.ElementTree as ET

import glob
# %matplotlib widget

import contextily as cx

from shapely.geometry.polygon import Polygon

import rioxarray

import cartopy.crs as ccrs
from cartopy.io import srtm
import cartopy

# %%
#%run functions.ipynb

# %% [markdown]
# # Functions

# %%
def head(filename,N=10):
    n=0
    with open(Path(filename)) as fp:
        for l in fp.readlines():
            if n<N:
                print(l,end="")
                n=n+1
                
def tail(filename,N=10):
    n=0
    with open(Path(filename)) as fp:
        lines=[i for i in fp.readlines()]
        Nlines=len(lines)
        for l in lines[Nlines-N:]:
            if n<N:
                print(l,end="")
                n=n+1
                
def ConvertNumeric(df,var):
    df[var]= pd.to_numeric(df[var],errors='coerce')
    
def testLogger(filename):
    Sep=","
    Data=[]
    with open(filename) as fp:
        for line in fp.readlines():
            row=line.split(Sep)
            Data.append(len(row))
    print(pd.DataFrame({"Columns":Data}).describe())
    
def ncolumnsLogger(filename):
    Sep=","
    Data=[]
    with open(filename) as fp:
        for line in fp.readlines():
            row=line.split(Sep)
            Data.append(len(row))
    return(np.median(np.array(Data)))

def readLogger(filename, nLines=18):
    DataString=""
    Sep=","
    with open(filename) as fp:
        for line in fp.readlines():
            row=line.split(Sep)
            if isinstance(nLines, list):
                if len(row) in nLines and re.match('\W*(\d{4})[/.-](\d{2})[/.-](\d{2})\s{1}(\d{2}):(\d{2}):(\d{2})\W*',row[0]):
                    DataString=DataString+line                
            else:
                if len(row) == nLines and re.match('\W*(\d{4})[/.-](\d{2})[/.-](\d{2})\s{1}(\d{2}):(\d{2}):(\d{2})\W*',row[0]):
                    DataString=DataString+line
    return(DataString)

def readRM(filename, nLines=18):
    DataString=""
    Sep=","
    with open(filename) as fp:
        for line in fp.readlines():
            row=line.split(Sep)
            if len(row) == nLines and re.match('\W*(\d{4})[/.-](\d{2})[/.-](\d{2})\s{1}(\d{2}):(\d{2}):(\d{2})\W*',row[0]):
                DataString=DataString+line
    return(DataString)

def lsR(dir,pattern=".csv",prefix="",postfix=""):
    list=[]
    for path,dirs,files in os.walk(Path(dir)):
        for f in files:
            if f.count(pattern) > 0 and f.startswith(prefix) and f.endswith(postfix):
                list.append(os.path.join(path,f))
    return(list)

def clearplots():
    plt.clf()
    
def readStation(file, authority, var):
    # Read the data file
    df=pd.read_excel(file,
                     skiprows=[0,1,3,4], 
                     parse_dates=[0], 
                     date_parser=custom_date_parser, 
                     index_col=0, 
                     na_values=['', '#N/A', '#N/A N/A', '#NA', '-1.#IND', '-1.#QNAN', '-NaN', '-nan','1.#IND','1.#QNAN', '<NA>', 'N/A', 'NA', 'NULL', 'NaN', 'n/a','nan', 'null','-999.0']
                    )
    df.index.name='Date'
    # Remove lines with a bad date index
    df=df.loc[~df.index.isnull()]
    # Remove lines where all data is missing
    df=df.dropna(axis=0, how='all')
    # Make sure that the variables are numeric
    df=df.apply(pd.to_numeric, errors='ignore')
    # Create short version
    df=df.stack()
    df=df.reset_index(level=[1])
    df.columns=['Site','Value']
    df['Variable']=var
    df['Unit']='ppm'
    df['Status']=0
    df['Authority']=authority
    df['Type']=""
    df=df.reset_index()
    df=df.set_index((df.Site + df.Variable + df.Unit + df.Date.astype(str) + df.Value.astype(str)).apply(hash))
    return(df)

def extractStation(df, Var, Site='', Type=''):
    df = df[(df['Variable']==Var)]
    if len(Site) > 0:
        df = df[(df['Site']==Site)]
    if len(Type) > 0 :
        df = df[(df['Type']==Type)]
    df = df.reset_index()
    df = df.set_index('Date')
    return(df)

def writeStation(dfRaw,df):
    df=df.dropna(subset=['index'])
    df=df.reset_index()
    df=df.set_index((df.Site + df.Variable + df.Unit + df.Date.astype(str) + df.Value.astype(str)).apply(hash))
    print("Setting ",len(df[df['Status']>0]),'status')
    dfRaw.loc[df[df['Status']>0].index, 'Status']=df[df['Status']>0]['Status']
    #return(dfRaw)
    
def stuckValue(df,Var='PM2.5 (ug/m3)',diff=0.1,stuckNumber=3):
    print("In stuckValue:",Var,diff,stuckNumber)
    df['diff']=(abs(df[Var]-df[Var].shift())>diff).astype(int)
    df['c'] = (df['diff'] != 0).cumsum()
    df['a'] = (df['c'] == 0).astype(int)
    df['streak'] = df.groupby( 'c' ).cumcount() + df['a']
    df.loc[df['streak'] > stuckNumber,'Status'] = 2
    df.drop(['streak', 'a','c','diff'], axis=1, inplace=True)
    df=df.dropna(subset=['index'])
    return(df[df['Status']==2])

months={1:'January',
        2:'February',
        3:'March',
        4:'April',
        5:'May',
        6:'June',
        7:'July',
        8:'August',
        9:'September',
        10:'October',
        11:'November',
        12:'December'}

output=[["Agent", "Period", "Standard", "Exceeds", "Average", "Interval", "N", "N exceeds", "Std Dev", "Median", "25%", "75%", "99%"]]



Vars={"PM10 (ug/m3)",
      "PM2.5 (ug/m3)",
      "SO2 (ppb)",
      "NO2 (ppb)",
      "H2S (ppb)",
      "CO (ppm)",
      "O3 (ppb)"} 

DataAvailable={'1D':1152,
               'A':367920,
               '8H':384,
               '4H':192,
               '1H':48} 

def is_leap_year(year):
    return int(year % 4 == 0 and (year % 100 != 0 or year % 400 == 0))

def numdays(month,year):
    days={1:31,2:28,3:31,4:30,5:31,6:30,7:31,8:31,9:30,10:31,11:30,12:31}
    if month == 2:
        return(days[month]+is_leap_year(year))
    else:
        return(days[month])

def confidence_interval(data, confidence=0.99):                                                                                                                                                                                                                                    
    a = 1.0*np.array(data)                                                                                                                                                                                                                                                         
    n = len(a)                                                                                                                                                                                                                                                                     
    m, se = np.mean(a), scipy.stats.sem(a)                                                                                                                                                                                                                                         
    h = se * sp.stats.t._ppf((1+confidence)/2., n-1)                                                                                                                                                                                                                               
    return( m-h, m+h)

def extractStationVars(df,Site="",Vars=[]):
    df=df[(df['Site']==Site)]
    df=pd.pivot_table(df,index=['Date'],columns=['Variable'],values=['Value'])
    df.index=pd.to_datetime(df.index)
    df.columns=df.columns.droplevel(0)
    if len(Vars) > 0:
        Vars=[v for v in Vars if v in df.columns]
        df=df[Vars]
    df=df.resample('1H').first()
    return(df)

# %% [markdown]
# # Visualisation functions

# %%
def plotdiurnalstats(df,var='PM10_logger (ug/m3)'):
    df['Time'] = df.index.map(lambda x: x.strftime("%H:00"))
    diurnal = df[['Time',var]].groupby('Time').describe()[var]
    fig, ax = plt.subplots(1, figsize=(7,6))
    ax.set_ylabel(var, fontsize=14, weight='bold')                                                                                                                                                                                                                           
    ax.set_xlabel('Time of Day', fontsize=14)                                                                                                                                                                                                                                    
    print("Plotting mean")                                                                                                                                                                                                                                                       
    ax.plot(diurnal.index, diurnal['50%'], 'g', linewidth=2.0,label=var)
    print("Plotting 75%")                                                                                                                                                                                                                                                        
    ax.plot(diurnal.index, diurnal['75%'], color='g')                                                                                                                                                                                                                            
    print("Plotting 25%")                                                                                                                                                                                                                                                        
    ax.plot(diurnal.index, diurnal['25%'], color='g') 
    ax.fill_between(diurnal.index, diurnal['50%'], diurnal['75%'], alpha=.25, facecolor='g')                                                                                                                                                                                      
    ax.fill_between(diurnal.index, diurnal['50%'], diurnal['25%'], alpha=.25, facecolor='g') 
    ax.set_xlim(0, 23);                                                                                                                                                                                                                                                          
    ax.set_xticks([i for i in range(0,24,3)])  
    plt.tight_layout() 
    
def plotdiurnal(df,var=''):
    df['decimalhour'] = df.index.hour+(df.index.minute/60)
    
    fig, ax = plt.subplots(figsize=(7,6))
    ax.set_ylabel(var, fontsize=14, weight='bold')                                                                                                                                                                                                                           
    ax.set_xlabel('Time of Day', fontsize=14)    
    
    ax.plot(df['decimalhour'].values, df[var].values, 'o', markersize=2, linewidth=0, label=var, alpha=0.3)

    #def format_coord(x, y):
    #    z=np.array_str(df[(df['decimalhour']==x)&(df[var]==y)].index.map(lambda x: x.strftime("%y/%m/%d %H:%M")).values)[1:34]
    #    return('x={}, y={}, date={}'%(x, y,z))

    #ax.format_coord = format_coord
    
    ax.set_xlim(0, 23);                                                                                                                                                                                                                                                          
    ax.set_xticks([i for i in range(0,24,3)])  
    plt.tight_layout() 
    df=df.drop(['decimalhour'], axis = 1)
    
def plottimeseries(df,var=''):
    fig, ax = plt.subplots(1,figsize=(7,6))
    df[[var]].plot(ax=ax)
    ax.set_ylabel(var, fontsize=14, weight='bold')                                                                                                                                                                                                                           
    ax.set_xlabel('', fontsize=14)
    
# Default function to read data format from SAAQIS database
def custom_date_parser(time):
    NoDates=['Max Date', 'Max Time', 'Minimum', 'Min Date', 'Min Time','Avg','Std','Data Percent','Num', 'Maximum']
    if time not in NoDates:
        try:
            time = datetime.datetime.strptime(time, "%H:%M %d/%m/%Y")
        except ValueError:
            time = time.replace('24:', '23:')
            time = datetime.datetime.strptime(time, "%H:%M %d/%m/%Y")
            time += datetime.timedelta(hours=1)
        except:
            return(np.nan)
        return(time)

# %%
def SummaryTable(df,month):
    days={1:31,2:28,3:31,4:30,5:31,6:30,7:31,8:31,9:30,10:31,11:30,12:31}
    ndur={'1D':1,'8H':3,'1H':24}
    ndays=days[month]
    pols=[["PM10",'1D',75,4],
          ["PM2.5",'1D',40,4],
          ["SO2","1H",134,88],
          ["SO2","1D",48,4],
          ["NO2","1H",106,88],
          ["CO","1H",26,88],
          ["CO","8H",8.7,11],
          ["O3","8H",61,11]]

    output=[["Agent", "Period", "Standard", "Exceeds", "Average", "Interval", "N", "N exceeds", "Std Dev", "Median", "25%", "75%", "99%","DataAvailable (%)"]]
    for p in pols:
        pname=p[0]
        pdur=p[1]
        paqs=p[2]
        pexc=p[3]
        #print("Doing",pname,pdur,paqs,pexc)
        if pdur == "A":
            t1=df[[pname]].dropna().resample('1M').mean()
            t2=df[[pname]].dropna().resample('1M').count()
            t2.columns=['N']
            if t2.sum()[0] < 34560:
                N=0
                Nexc=np.nan
            else:
                N=1
                if t1.mean()[0] > paqs:
                    Nexc=1
                else:
                    Nexc=0
        else:
            if pdur == '8H':
                t1=df[[pname]].resample('1H').mean().rolling(window=8,min_periods=4).mean()
                t2=df[[pname]].dropna().resample('1H').mean().rolling(window=8,min_periods=4).count()
            else:
                t1=df[[pname]].dropna().resample(pdur).mean()
                t2=df[[pname]].dropna().resample(pdur).count()
                # t1.ix[df[pname]<10,pname]=np.nan
                t2.columns=['N']
                t=pd.concat([t1,t2],axis=1)
                t.loc[t['N']<DataAvailable[pdur],pname]=np.nan
                N=len(t[pname].dropna())
                Nexc=len(t[t[pname]>paqs])
        if N>4:
            #print(t[pname].dropna().describe())
            if N<30:
                CIs=confidence_interval(t[pname].dropna().values)
                #bootstrap.ci(data=t[pname].dropna(),statfunction=sp.mean,alpha=0.05)
            elif N>5:
                CIs=confidence_interval(t[pname].dropna().values)
            else:
                CIs=["",""]
            Pave=t[pname].mean()
            Pstd=t[pname].std()
            P50=t[pname].quantile(0.5)
            P25=t[pname].quantile(0.25)
            P75=t[pname].quantile(0.75)
            P99=t[pname].quantile(0.99)
        else:
            CIs=[np.nan,np.nan]
            Pave=t[pname].mean()
            Pstd=np.nan
            P50=np.nan
            P25=np.nan
            P75=np.nan
            P99=np.nan
        #print(t[pname].mean(),CIs,N)
        DA=N/(ndays*ndur[pdur])*100
        output.append([pname,pdur,paqs,pexc,"%.0f" % (Pave),"%.0f-%.0f" % (CIs[0],CIs[1]),N,Nexc,"%.0f" % (Pstd),"%.0f" % (P50),"%.0f" % (P25),"%.0f" % (P75),"%.0f" % (P99),"%.0f" % (DA)])
        a=np.array(output)
        df2=pd.DataFrame(data=a[1:,1:],index=a[1:,0],columns=a[0,1:])
        df2=df2.replace("nan-nan", "")
        df2=df2.replace("nan", "")
        #print(t)
    return(df2)

# %% [markdown]
# # Directories

# %%
HomeDir= Path('C:\\Users\\GerhardtBotha\\OneDrive - C4 EcoSolutions\\Documents\\Study\\MSc')
DataDir = Path('C:\\Users\\GerhardtBotha\\OneDrive - C4 EcoSolutions\\Documents\\Study\\MSc\\Data')
FigDir = Path(HomeDir/'Figures')
GisDir = Path(HomeDir/'Data/GIS/Data')
RadarDir = Path(HomeDir/'Data/Radar')
FireDir = Path(HomeDir/'Data/FIRE')

# %% [markdown]
# ## Import AQMS Data

# %%
os.listdir(DataDir/'SAAQIS')
# Out:
# ['Highveld_SAAQIS_Stations.csv',
#  'Highveld_SAAQIS_Stations.qmd',
#  'SAAQIS_2013_2017_Level0.csv',
#  'SAAQIS_2013_2017_Level1.csv',
#  'SAAQIS_Highveld.csv',
#  'SAAQIS_Highveld.qmd',
#  'SAAQIS_Level0.csv',
#  'SAAQIS_Level1.csv',
#  'SAAQIS_Level2.csv',
#  'SAAQIS_Stations_Level0.cpg',
#  'SAAQIS_Stations_Level0.dbf',
#  'SAAQIS_Stations_Level0.prj',
#  'SAAQIS_Stations_Level0.shp',
#  'SAAQIS_Stations_Level0.shx',
#  'SAAQIS_Stations_Level0_Coords.csv',
#  'SAAQIS_Stations_Level1.cpg',
#  'SAAQIS_Stations_Level1.csv',
#  'SAAQIS_Stations_Level1.dbf',
#  'SAAQIS_Stations_Level1.prj',
#  'SAAQIS_Stations_Level1.shp',
#  'SAAQIS_Stations_Level1.shx',
#  'site_info.xlsx']

# %%
dflevel0 = pd.read_csv(os.path.join(DataDir,'SAAQIS_Level0.csv'), parse_dates=[0], index_col=0)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 dflevel0 = pd.read_csv(os.path.join(DataDir,'SAAQIS_Level0.csv'), parse_dates=[0], index_col=0)
#
# File ~\anaconda3\envs\msc_env\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~\anaconda3\envs\msc_env\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# ...

# %%
dflevel1 = pd.read_csv(DataDir/'SAAQIS_Level1.csv', parse_dates=[0], index_col=0)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 dflevel1 = pd.read_csv(DataDir/'SAAQIS_Level1.csv', parse_dates=[0], index_col=0)
#
# File ~\anaconda3\envs\msc_env\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~\anaconda3\envs\msc_env\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# ...

# %% [markdown]
# ### Make sure Time Zone is local

# %%
dflevel1 = dflevel1.tz_localize('Africa/Johannesburg')

# %%
dflevel0 = dflevel0.tz_localize('Africa/Johannesburg')

# %% [markdown]
# # Objective 02: Radar observations of plumes

# %% [markdown]
# #### Import stations

# %%
stations = gpd.read_file(GisDir/'SAAQIS_AQMS/SA_SAAQIS_AQMS.shp')

# %%
stations.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
stations.explore()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 stations.explore()
#
# File ~\anaconda3\envs\msc_env\lib\site-packages\pandas\core\generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'GeoDataFrame' object has no attribute 'explore'

# %% [markdown]
# #### Import radar

# %%
radar = gpd.read_file(GisDir/'Radar.shp')
radar = gpd.GeoDataFrame(radar, geometry=gpd.points_from_xy(radar.xcoord, radar.ycoord))
radar = radar.set_crs(4326)
# Out:
# C:\Users\GerhardtBotha\anaconda3\envs\msc_env\lib\site-packages\geopandas\array.py:275: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   return GeometryArray(vectorized.points_from_xy(x, y, z), crs=crs)

# %%
radar.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %% [markdown]
# #### Import country

# %%
South_Africa = gpd.read_file(GisDir/'SA.shp')

# %%
South_Africa.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %% [markdown]
# **Check CRS**

# %%
print('Stations:',stations.crs)
print('Radar:',radar.crs)
print('SA:',South_Africa.crs)
# Out:
# Stations: epsg:4326
# Radar: epsg:4326
# SA: epsg:4326

# %% [markdown]
# ### Reproject Layers to Hartebeeshoek EPSG:9221

# %%
stations = stations.to_crs(epsg=9221)
radar = radar.to_crs(epsg=9221)
South_Africa = South_Africa.to_crs(epsg=9221)

# %% [markdown]
# **Plot radar and stations**

# %%
fig, ax = plt.subplots(figsize=(10,10))


radar_range = radar.buffer(200000)

South_Africa.boundary.plot(ax=ax)

radar_range.plot(ax=ax)

stations.plot(column='Type',
                categorical=True,
                legend=True,
                cmap="viridis",
                markersize=45,
                ax=ax)

#cx.add_basemap(ax,crs=South_Africa.crs,url = cx.providers.OpenStreetMap.Mapnik)

ax.set_title('Station Locations according to station type')
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Days with plumes

# %%
plumed = pd.read_csv('Data/Radar/PlumesDaysRadar.csv', parse_dates=[1], index_col=1)

# %%
plumed = plumed.loc[plumed['Satellite Plume']=='Clear']

# %%
plumed.drop(columns={'Num','Radar Plume','Unnamed: 4'}, inplace=True)

# %%
plumed.columns
# Out:
# Index(['Satellite Plume'], dtype='object')

# %%
plumedays = []
for i in plumed.index:
    i = str(i)
    i = i.split(" ")[0]
    i = i.replace("-",'')
    plumedays.append(i)

# %%
plumedays
# Out:
# ['20130526',
#  '20130529',
#  '20130531',
#  '20130601',
#  '20130602',
#  '20130603',
#  '20130604',
#  '20130605',
#  '20130606',
#  '20130607',
#  '20130608',
#  '20130611',
#  '20130612',
#  '20130613',
#  '20130614',
#  '20130615',
#  '20130616',
#  '20130617',
#  '20130618',
#  '20130619',
#  '20130620',
#  '20130621',
#  '20130622',
#  '20130623',
#  '20130625',
#  '20130626',
#  '20130814',
#  '20130815',
#  '20140621',
#  '20140622',
#  '20140623',
#  '20140624',
#  '20140625',
#  '20140707',
#  '20140708',
#  '20140709',
#  '20140710',
#  '20140711',
#  '20140712',
#  '20140713',
#  '20140714',
#  '20140716',
#  '20140717',
#  '20140719',
#  '20140720',
#  '20140721',
#  '20140722',
#  '20140723',
#  '20140724',
#  '20140725',
#  '20140726',
#  '20140727',
#  '20140728',
#  '20140729',
#  '20140909',
#  '20140910',
#  '20140911',
#  '20140915',
#  '20140916',
#  '20140917',
#  '20150503',
#  '20150504',
#  '20150505',
#  '20150506',
#  '20150514',
#  '20150515',
# ...

# %% [markdown]
# ## Radar Data: dBZ

# %% [markdown]
# ### Import extracted data

# %%
RadarDir
# Out:
# WindowsPath('C:/Users/GerhardtBotha/OneDrive - C4 EcoSolutions/Documents/Study/MSc/Data/Radar')

# %%
Extracted_dBZ = pd.read_csv(RadarDir/'Plume/dBZ/MdvExtractPoint_dBZ.csv', index_col=0, parse_dates=[0])

# %% [markdown]
# ### Make sure Extracted DBZ is in Local Time

# %%
Extracted_dBZ = Extracted_dBZ.tz_convert('Africa/Johannesburg')

# %% [markdown]
# ### Merge with Level0 Data

# %%
Extracted_dBZ.reset_index(inplace=True)

# %%
dflevel2['']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [32], line 1
# ----> 1 dflevel2['']
#
# NameError: name 'dflevel2' is not defined

# %%
dflevel0.reset_index(inplace=True)

# %%
dflevel2 = pd.merge_ordered(dflevel0, Extracted_dBZ, on=['Date','Site'])

dflevel2.set_index('Date', inplace=True)

# %% [markdown]
# # Plume Tracks

# %% [markdown]
# ## Import tracks

# %%
os.listdir(os.path.join(RadarDir,'Plume','xml'))
# Out:
# ['plumeshapefiles_phase0.cpg',
#  'plumeshapefiles_phase0.dbf',
#  'plumeshapefiles_phase0.shp',
#  'plumeshapefiles_phase0.shx',
#  'plumeshapefiles_phase0_projected_9221.cpg',
#  'plumeshapefiles_phase0_projected_9221.dbf',
#  'plumeshapefiles_phase0_projected_9221.prj',
#  'plumeshapefiles_phase0_projected_9221.qmd',
#  'plumeshapefiles_phase0_projected_9221.shp',
#  'plumeshapefiles_phase0_projected_9221.shx',
#  'plumesoverstations_phase0_projected_9221.cpg',
#  'plumesoverstations_phase0_projected_9221.dbf',
#  'plumesoverstations_phase0_projected_9221.prj',
#  'plumesoverstations_phase0_projected_9221.shp',
#  'plumesoverstations_phase0_projected_9221.shx']

# %%
filtered_plumes = gpd.read_file(os.path.join(RadarDir,'Plume','xml','plumesoverstations_phase0_projected_9221.shp'))

# %%
filtered_plumes
# Out:
#         index       unique_id  Track_ID                 Time       Day  \
# 0           3  20130526_106.0     106.0  2013-05-26T08:23:23  20130526
# 1           4  20130526_109.0     109.0  2013-05-26T09:47:23  20130526
# 2          18  20130526_152.0     152.0  2013-05-26T09:59:23  20130526
# 3          20  20130526_158.0     158.0  2013-05-26T10:17:23  20130526
# 4          30  20130526_180.0     180.0  2013-05-26T10:23:23  20130526
# ...       ...             ...       ...                  ...       ...
# 131764  33371  20160912_401.0     401.0  2016-09-12T18:34:57  20160912
# 131765  34150  20160921_397.0     397.0  2016-09-21T14:04:51  20160921
# 131766  34155  20160921_401.0     401.0  2016-09-21T14:04:51  20160921
# 131767  34834  20160922_397.0     397.0  2016-09-22T13:10:55  20160922
# 131768  34839  20160922_401.0     401.0  2016-09-22T12:46:56  20160922
#
#         age (secon  cell_top (  max_dbz (d    ID_parent ID_child (  \
# ...

# %% [markdown]
# ### Import fire occurances

# %% [markdown]
# #### MODIS Thermal Anomalies

# %%
modisfire = gpd.read_file(FireDir/'MODIS_C6.1_RadarRange_2013_2016.shp')
modisfire.set_index('ACQ_DATE', inplace=True)

# %% [markdown]
# #### VIIRS Thermal Anomalies

# %%
viirsfire = gpd.read_file(FireDir/'VIIRS_C2_RadarRange_2013_2016.shp')
viirsfire.set_index('ACQ_DATE', inplace=True)

# %% [markdown]
# #### Fire Atlas

# %%
fireatlas = gpd.read_file(FireDir/'GlobalFireAtlas_RadarRange_2013_2016.shp')
fireatlas.set_index('start_date', inplace=True)

# %% [markdown]
# ### Reproject Layers to Hartebeeshoek EPSG:9221

# %%
modisfire = modisfire.to_crs(epsg=9221)
viirsfire = viirsfire.to_crs(epsg=9221)
fireatlas = fireatlas.to_crs(epsg=9221)

# %% [markdown]
# # Plume impacts on AQMS data

# %%
ShapefileP.resample('1H').mean().describe().to_csv('SummaryStats.csv')

# %% [markdown]
# #### Check CRS of input files

# %%
print(stations.crs)
print(ShapefileP.crs)
# Out:
# epsg:9221
# epsg:9221

# %%
ShapefileP = ShapefileP.to_crs(epsg=9221)

# %% [markdown]
# ### Select stations in polygon

# %%
pointInPolys= gpd.tools.sjoin(stations, ShapefileP, predicate="within", how='right')

# %%
pointInPolys.dropna(how='any', inplace=True)

# %%
pointInPolys.reset_index(inplace=True)

# %%
pointInPolys['datetime'] = pd.to_datetime(pointInPolys['datetime'])
pointInPolys.set_index('datetime', inplace=True)
#pointInPolys = pointInPolys.tz_localize('UTC')
pointInPolys = pointInPolys.tz_convert('Africa/Johannesburg')
pointInPolys.index.names = ['Date']
pointInPolys.rename(columns={'index_left':'Track'}, inplace=True)

# %%
pointInPolys
# Out:
#                            Track  field_1        Site  \
# Date
# 2013-06-17 17:29:00+02:00   50.0     66.0     Tembisa
# 2013-06-17 14:41:00+02:00   40.0     12.0   Diepkloof
# 2013-06-17 14:17:00+02:00   48.0     29.0      Kendal
# 2013-06-17 14:35:00+02:00   43.0     74.0      Xanadu
# 2013-06-17 16:29:00+02:00   19.0     31.0  Kliprivier
# 2013-06-17 16:53:00+02:00   48.0     29.0      Kendal
# 2013-06-17 18:23:00+02:00   40.0     12.0   Diepkloof
# 2013-06-18 13:36:00+02:00   50.0     66.0     Tembisa
# 2013-06-19 17:11:00+02:00   50.0     66.0     Tembisa
# 2013-06-19 16:35:00+02:00   46.0     11.0      Delmas
# 2013-06-19 16:59:00+02:00   26.0     73.0   Wattville
# 2013-06-19 15:23:00+02:00   26.0     73.0   Wattville
#
#                                                         Type   Latitude  \
# Date
# 2013-06-17 17:29:00+02:00           Residential - Low Income -25.994500
# 2013-06-17 14:41:00+02:00                              Urban -26.250733
# ...

# %%
pointInPolys.crs
# Out:
# <Derived Projected CRS: EPSG:9221>
# Name: Hartebeesthoek94 / ZAF BSU Albers 25E
# Axis Info [cartesian]:
# - N[north]: Northing (metre)
# - E[east]: Easting (metre)
# Area of Use:
# - name: South Africa - mainland - onshore and offshore.
# - bounds: (13.33, -38.17, 36.54, -22.13)
# Coordinate Operation:
# - name: South Africa Basic Survey Unit Albers 25E
# - method: Albers Equal Area
# Datum: Hartebeesthoek94
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %% [markdown]
# ### Plot tracks

# %%
pointInPolys.Site.unique()
# Out:
# array(['Tembisa', 'Diepkloof', 'Kendal', 'Xanadu', 'Kliprivier', 'Delmas',
#        'Wattville'], dtype=object)

# %%
stations.crs
# Out:
# <Derived Projected CRS: EPSG:9221>
# Name: Hartebeesthoek94 / ZAF BSU Albers 25E
# Axis Info [cartesian]:
# - N[north]: Northing (metre)
# - E[east]: Easting (metre)
# Area of Use:
# - name: South Africa - mainland - onshore and offshore.
# - bounds: (13.33, -38.17, 36.54, -22.13)
# Coordinate Operation:
# - name: South Africa Basic Survey Unit Albers 25E
# - method: Albers Equal Area
# Datum: Hartebeesthoek94
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
fig, ax = plt.subplots(figsize=(14,8))

pointInPolys.plot(ax=ax, alpha=0.6, label='Smoke Plumes')

for x, y, label in zip(stationsday.centroid.x,stationsday.centroid.y, stationsday['Site']):
    ax.annotate(label, xy=(x,y), xytext=(4,4), textcoords='offset points')
    
stationsday = stations.loc[stations['Site'].isin(pointInPolys.Site.unique())]

stationsday.plot(ax=ax, label='SAAQS Stations')

dayshapes = ShapefileP.buffer(0.05)
daymodis = gpd.clip(modisfire.loc[day], dayshapes)
dayviirs = gpd.clip(viirsfire.loc[day], dayshapes)
dayatlas = gpd.clip(fireatlas.loc[day], dayshapes)

daymodis.plot(ax=ax, color='r', label='MODIS Thermal Anomaly')
dayviirs.plot(ax=ax, color='orange', label='VIIRS Thermal Anomaly')


cx.add_basemap(ax, crs=stations.crs,source = cx.providers.Stamen.TonerHybrid)


ax.set_axis_off()

plt.legend(loc='upper right')

plt.savefig(FigDir/'Plumes_Stations_2013_06.png', dpi=300)

# %% [markdown]
# ### Get monitoring data

# %% [markdown]
# #### Check for monitoring data

# %%
data_avail = []

for i in pointInPolys['Site'].unique():
    print(i)
    dftmp = pointInPolys.loc[pointInPolys['Site']==i]
    days = dftmp.Day.unique()
    for day in days:
        print(day)
        aqms = dflevel0.loc[dflevel0['Site']==i]['{}'.format(day)]
        print(len(aqms))
# Out:
# Tembisa
# 2013-06-17
# 0
# 2013-06-18
# 0
# 2013-06-19
# 0
# Diepkloof
# 2013-06-17
# 144
# Kendal
# 2013-06-17
# 0
# Xanadu
# 2013-06-17
# 0
# Kliprivier
# 2013-06-17
# 144
# Delmas
# 2013-06-19
# 0
# Wattville
# 2013-06-19
# 0

# %% [markdown]
# #### Functions to get different data sources

# %%
# Extract the pixel reflectivity for the site
def extractDBZ(df,Site=''):
    if len(Site) > 0:
        df = df.loc[df['Site']==Site,'dBZ']
        df = df.reset_index()
        df = df.set_index('Date')
        return(df)

# %%
# Extract the Track properties and resample to compare with AQMS data 
def extractPlume(df,Site=''):
    if len(Site) > 0:
        df = df.loc[df['Site']==Site]
    df = df.groupby('Site').resample('1H').mean()
    df = df.reset_index()
    df = df.dropna(how='any')
    df = df.set_index('Date')
    return(df)

# %%
# Get the track of the plumes (track gets lost when resampled)
def extractTrack(df,Site=''):
    if len(Site) > 0:
        df = df.loc[df['Site']==Site]
    df = df.reset_index()
    df = df.dissolve(by=['Track'])
    df = df.set_index('Date')
    return(df)

# %% [markdown]
# #### Integrate different data sources and plot the Plume, Radar and AQMS data

# %%
rcParams['font.family'] = 'serif' 

for site in pointInPolys['Site'].unique():
    dftmp = pointInPolys.loc[pointInPolys['Site']==site]
    days = dftmp.Day.unique()
    for day in days:
        aqms = dflevel0.loc[dflevel0['Site']==site]['{}'.format(day)]
        if len(aqms) > 0:
            AQMS = extractStationVars(dflevel0,Site=site)
            AQMS = AQMS.loc[day]
            Plume = extractPlume(pointInPolys,Site=site)
            Plume = Plume.loc[day]
            DBZ = extractDBZ(Extracted_dBZ, Site=site)
            DBZ = DBZ.loc[day]
            Track = extractTrack(pointInPolys,Site=site)
        
            Combined = pd.concat([AQMS, DBZ, Plume])
            
            
            days = Plume.index.floor('D').unique()
            days = days.to_list()
        
            
            fig, ax = plt.subplots(1,2, figsize=(14,8))
            
            plt_date = Combined.index
            for i in ['PM10','PM2.5','Zmax dbz', 'Zmean dbz','dBZ']:
                if i in Combined.columns:
                    ax[0].plot_date(plt_date, Combined[i], linestyle='solid', label=i)
            
                    ax[0].tick_params(axis='x', rotation=40)
            
                    ax[0].legend()
                
            dayshapes = Track.buffer(0.05)
            daymodis = gpd.clip(modisfire.loc[day], dayshapes)
            dayviirs = gpd.clip(viirsfire.loc[day], dayshapes)
            dayatlas = gpd.clip(fireatlas.loc[day], dayshapes)
            
            daymodis.plot(ax=ax[1], color='r', label='MODIS Thermal Anomaly')
            dayviirs.plot(ax=ax[1], color='y', label='VIIRS Thermal Anomaly')
            
            radar.plot(ax=ax[1], marker='*', markersize=45, label='Radar')
            
            Track.plot(ax=ax[1], alpha=0.5)    
            
            stations.loc[stations['Site']==site].plot(ax=ax[1], label='{}'.format(site), marker='D',markersize=50, color='black')
            
            ax[1].legend()
            
            
            
            
            
            
            
            
            plt.suptitle('{} \n {}'.format(site, day), fontsize=20)
            
            plt.tight_layout()
            
            plt.savefig(FigDir/'Timeseries_Plume_{}_{}.png'.format(site,day), dpi=300)

# %% [markdown]
# ## Plot XMLPlumes and Stations Data

# %%
# Extract the pixel reflectivity for the site
def extractDBZ(df,Site=''):
    df = df.loc[df['Site']==Site,'dBZ']
    df = df.reset_index()
    df = df.set_index('Date')
    df = df.resample('1H').mean()
    return(df)

# Extract the Track properties and resample to compare with AQMS data 
def extractPlume(df,Site=''):
    df = df.loc[df['Site']==Site]
    df = df.groupby('Site').resample('1H').mean()
    df = df.dropna(how='any')
    return(df)


# Get the track of the plumes (track gets lost when resampled)
def extractTrack(df,Site=''):
    df = df.loc[df['Site']==Site]
    df = df.reset_index()
    df = df.dissolve(by=['Track'])
    df = df.set_index('Date')
    return(df)

# %%
def extractPlumeVars(aqms,dbz,plume,Site="",Vars=[]):
    aqms_df = extractStationVars(aqms, Site=Site)
    dbz_df = extractDBZ(dbz, Site=Site)
    plume_df = extractPlume(plume, Site=Site)
    
    df = pd.concat([aqms_df, dbz_df, plume_df], axis=1)
    df = df.drop(columns={'Latitude', 'Longitude','Track'})
    try:
        df = df[['PM10','PM2.5','age (seconds)','max_dbz (dbz)','dBZ']]
        df = df.dropna(how='all')
    except:
        print('No data for:',Site)
    return(df)

# %% [markdown]
# # Import Shapefile from XML Plumes

# %%
os.listdir(os.path.join(RadarDir,'Plume','xml'))
# Out:
# ['plumeshapefiles_phase0.cpg',
#  'plumeshapefiles_phase0.dbf',
#  'plumeshapefiles_phase0.shp',
#  'plumeshapefiles_phase0.shx',
#  'plumeshapefiles_phase0_projected_9221.cpg',
#  'plumeshapefiles_phase0_projected_9221.dbf',
#  'plumeshapefiles_phase0_projected_9221.prj',
#  'plumeshapefiles_phase0_projected_9221.qmd',
#  'plumeshapefiles_phase0_projected_9221.shp',
#  'plumeshapefiles_phase0_projected_9221.shx',
#  'plumesoverstations_phase0_projected_9221.cpg',
#  'plumesoverstations_phase0_projected_9221.dbf',
#  'plumesoverstations_phase0_projected_9221.prj',
#  'plumesoverstations_phase0_projected_9221.shp',
#  'plumesoverstations_phase0_projected_9221.shx']

# %%
plume_database = gpd.read_file(os.path.join(RadarDir,'Plume','xml','plumeshapefiles_phase0_projected_9221.shp'))

# %%
plume_database.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 35426 entries, 0 to 35425
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   unique_id   35426 non-null  object
#  1   Track_ID    35426 non-null  float64
#  2   Time        35426 non-null  object
#  3   Day         35426 non-null  object
#  4   age (secon  35426 non-null  float64
#  5   cell_top (  35426 non-null  float64
#  6   max_dbz (d  35426 non-null  float64
#  7   ID_parent   34600 non-null  object
#  8   ID_child (  34531 non-null  object
#  9   area        35426 non-null  float64
#  10  geometry    35426 non-null  geometry
# dtypes: float64(5), geometry(1), object(5)
# memory usage: 3.0+ MB

# %% [markdown]
# ## Select plumes over stations

# %%
stations = gpd.read_file(GisDir/'SAAQIS_AQMS/SA_SAAQIS_AQMS.shp')

# %% [markdown]
# **Check CRS**

# %%
plume_database.crs
# Out:
# <Projected CRS: PROJCS["Hartebeesthoek94_ZAF_BSU_Albers_25E",GEOGC ...>
# Name: Hartebeesthoek94_ZAF_BSU_Albers_25E
# Axis Info [cartesian]:
# - [east]: Easting (metre)
# - [north]: Northing (metre)
# Area of Use:
# - undefined
# Coordinate Operation:
# - name: unnamed
# - method: Albers Equal Area
# Datum: Hartebeesthoek94
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
stations.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
# Set CRS
stations = stations.to_crs(plume_database.crs)

# %% [markdown]
# **Explode multipolygons to single**

# %%
plume_database = plume_database.explode()
plume_database = plume_database.reset_index(drop=True)
# Out:
# C:\Users\GerhardtBotha\anaconda3\envs\msc_env\lib\site-packages\geopandas\geoseries.py:843: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for idx, s in self.geometry.iteritems():

# %% [markdown]
# **Perform spatial join**

# %%
pointInXMLPolys = gpd.sjoin(plume_database,stations, op="contains", how='inner')

#pointInXMLPolys.dropna(how='any', inplace=True)

#pointInXMLPolys.reset_index(inplace=True)

#pointInXMLPolys.set_index('Time', inplace=True)

#pointInXMLPolys = pointInXMLPolys.tz_localize('UTC')
#pointInXMLPolys = pointInXMLPolys.tz_convert('Africa/Johannesburg')
#pointInXMLPolys.index.names = ['Date']

# %% [markdown]
# **Export**

# %%
pointInXMLPolys.to_file(os.path.join(RadarDir,'Plume','xml','plumesoverstations_phase0_projected_9221.shp'))
# Out:
# C:\Users\GerhardtBotha\anaconda3\envs\msc_env\lib\site-packages\geopandas\io\file.py:299: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   pd.Int64Index,
# C:\Users\GerhardtBotha\AppData\Local\Temp\ipykernel_31340\2718540128.py:1: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   pointInXMLPolys.to_file(os.path.join(RadarDir,'Plume','xml','plumesoverstations_phase0_projected_9221.shp'))

# %%
test = pointInXMLPolys.loc[(pointInXMLPolys['Day']=='20130619')&(pointInXMLPolys['area']>700)]

# %%
test.columns
# Out:
# Index(['index', 'unique_id', 'Track_ID', 'Time', 'Day', 'age (secon',
#        'cell_top (', 'max_dbz (d', 'ID_parent', 'ID_child (', 'area',
#        'geometry', 'index_right', 'field_1', 'Site', 'Type', 'Latitude',
#        'Longitude'],
#       dtype='object')

# %%
import folium
from folium.plugins import MousePosition


test = test.to_crs(4326)

# Create a folium map centered at the mean coordinates of the polygons
m = folium.Map(location=[test.centroid.y.mean(), test.centroid.x.mean()], zoom_start=10)

# Add the polygons to the map
folium.GeoJson(test).add_to(m)

folium.GeoJson(stations).add_to(m)

# add the polygons to the map with tooltips
folium.GeoJson(
    test,
    tooltip=folium.features.GeoJsonTooltip(
        fields=['area', 'Track_ID', 'age (secon'],
        aliases=['area', 'Track_ID', 'age'],
        labels=True,
        sticky=False
    )
).add_to(m)

# Display the map
m
# Out:
# C:\Users\GerhardtBotha\AppData\Local\Temp\ipykernel_31340\4183212391.py:8: UserWarning:
#
# Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#
# C:\Users\GerhardtBotha\AppData\Local\Temp\ipykernel_31340\4183212391.py:8: UserWarning:
#
# Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
# ...

# %%
fig, ax = plt.subplots()

test.plot(ax=ax)
# Out:
# <AxesSubplot: >

# %%
pointInXMLPolys.loc[(pointInXMLPolys['Day']=='20130619')&(pointInXMLPolys['Site']=='Tembisa')&(pointInXMLPolys['area']>1000)].plot()
# Out:
# <AxesSubplot: >
